# %%
import os
print(os.name)
# Out:
# posix

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
x=dict()
for i in range(1,16):
  x[i]=pow(i,2)
print(x)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}
